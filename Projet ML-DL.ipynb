# %% [markdown]
# # **Heart Attack**

# %% [markdown]
# #**Exploration et pré-traitement des données**

# %%
import pandas as pd
import numpy as np

# %%
file_path = r'C:\Users\hp\Desktop\Projet_ML_DL_2023-2024\heart (1).csv'

df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.shape
# Out:
# (303, 14)

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trtbps    303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalachh  303 non-null    int64
#  8   exng      303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slp       303 non-null    int64
#  11  caa       303 non-null    int64
#  12  thall     303 non-null    int64
#  13  output    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df["age"].unique()
# Out:
# array([63, 37, 41, 56, 57, 44, 52, 54, 48, 49, 64, 58, 50, 66, 43, 69, 59,
#        42, 61, 40, 71, 51, 65, 53, 46, 45, 39, 47, 62, 34, 35, 29, 55, 60,
#        67, 68, 74, 76, 70, 38, 77], dtype=int64)

# %%
df["sex"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df["cp"].unique()
# Out:
# array([3, 2, 1, 0], dtype=int64)

# %%
df["output"].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
df.describe()
# Out:
#               age         sex          cp      trtbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg    thalachh        exng     oldpeak         slp         caa  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %% [markdown]
# # **Statistical Description of Categorical Variables**

# %%
df_categorical = df[["sex", "cp", "fbs", "restecg", "exng", "slp", "caa", "thall", "output"]]

unique_counts = df_categorical.nunique()
unique_values = df_categorical.apply(lambda x: x.unique())

pd.DataFrame({"Number of Unique Values": unique_counts, "Unique Values": unique_values})
# Out:
#          Number of Unique Values    Unique Values
# sex                            2           [1, 0]
# cp                             4     [3, 2, 1, 0]
# fbs                            2           [1, 0]
# restecg                        3        [0, 1, 2]
# exng                           2           [0, 1]
# slp                            3        [0, 2, 1]
# caa                            5  [0, 2, 1, 3, 4]
# thall                          4     [1, 2, 3, 0]
# output                         2           [1, 0]

# %% [markdown]
# # **Statistical Description of Numerical Variables**

# %%
df_numerical = df.drop(df_categorical.columns, axis=1)

numerical_stats = df_numerical.describe().T

print(numerical_stats)
# Out:
#           count        mean        std    min    25%    50%    75%    max
# age       303.0   54.366337   9.082101   29.0   47.5   55.0   61.0   77.0
# trtbps    303.0  131.623762  17.538143   94.0  120.0  130.0  140.0  200.0
# chol      303.0  246.264026  51.830751  126.0  211.0  240.0  274.5  564.0
# thalachh  303.0  149.646865  22.905161   71.0  133.5  153.0  166.0  202.0
# oldpeak   303.0    1.039604   1.161075    0.0    0.0    0.8    1.6    6.2

# %% [markdown]
# # **Data Cleansing**

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trtbps      0
# chol        0
# fbs         0
# restecg     0
# thalachh    0
# exng        0
# oldpeak     0
# slp         0
# caa         0
# thall       0
# output      0
# dtype: int64

# %%
df[df.duplicated()]
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 164   38    1   2     138   175    0        1       173     0      0.0    2
#
#      caa  thall  output
# 164    4      2       1

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df.drop_duplicates()
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0     63    1   3     145   233    1        0       150     0      2.3    0
# 1     37    1   2     130   250    0        1       187     0      3.5    0
# 2     41    0   1     130   204    0        0       172     0      1.4    2
# 3     56    1   1     120   236    0        1       178     0      0.8    2
# 4     57    0   0     120   354    0        1       163     1      0.6    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 298   57    0   0     140   241    0        1       123     1      0.2    1
# 299   45    1   3     110   264    0        1       132     0      1.2    1
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 301   57    1   0     130   131    0        1       115     1      1.2    1
# 302   57    0   1     130   236    0        0       174     0      0.0    1
#
#      caa  thall  output
# 0      0      1       1
# ...

# %% [markdown]
# # **Distribution of Output**

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize = (6,6))
plt.pie(df.output.value_counts(), labels = df.output.value_counts().index, autopct='%1.1f%%', startangle = 90)
plt.title("Distribution of patients with heart attack")
plt.show()

# %%
import seaborn as sns

# %%
fig, ax = plt.subplots(3, 3, figsize=(22, 15))  # Updated to 3 rows

for i, col in enumerate(df_categorical.columns):
    x = i // 3
    y = i % 3

    graph = sns.countplot(data=df_categorical, x=col, hue='output', ax=ax[x, y])

    ax[x, y].set_xlabel(col, fontsize=15)
    ax[x, y].set_ylabel('Count', fontsize=12)
    ax[x, y].grid(color='lightgrey')

    for p in graph.patches:
        ax[x, y].annotate('{}'.format(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height() + 1),
                          ha='center', fontsize=10, fontweight="bold")

plt.suptitle('Countplot of Categorical Variables by Output', fontsize=20)
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()

# %%
fig, ax = plt.subplots(2, 3, figsize=(22, 15))

for i, col in enumerate(df_numerical.columns):
    x = i // 3  # Corrected indexing for rows
    y = i % 3   # Corrected indexing for columns

    values, bin_edged = np.histogram(
        df_numerical[col],
        range=(np.floor(df_numerical[col].min()), np.ceil(df_numerical[col].max()))
    )

    graph = sns.histplot(
        data=df_numerical, x=col, bins=bin_edged, kde=True, ax=ax[x, y],
        alpha=0.6, line_kws={'lw': 3}
    )

    ax[x, y].set_xlabel(col, fontsize=15)
    ax[x, y].set_ylabel('Count', fontsize=12)
    ax[x, y].set_xticks(np.round(bin_edged, 1))
    ax[x, y].set_xticklabels(ax[x, y].get_xticks(), rotation=45)
    ax[x, y].grid(color='lightgrey')

    for j, p in enumerate(graph.patches):
        ax[x, y].annotate('{}'.format(p.get_height()), (p.get_x() + p.get_width() / 2, p.get_height() + 1),
                          ha='center', fontsize=10, fontweight="bold")

ax[1, 2].axis('off')  # Corrected indexing for the last subplot
plt.suptitle('Distribution of Numerical Variables', fontsize=20)
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()

# %% [markdown]
# # **Pearson Correlation**

# %%
target = 'price_range'
corr = df.corr()

plt.figure(figsize=(16, 8))
sns.heatmap(corr, annot=True, fmt='.2f', linewidths=0.2)
plt.show()

# %%
df = df.drop(columns = ["chol", 'fbs'], axis = 1)

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
# !pip install -U imbalanced-learn
# Out:
# ...
#   Obtaining dependency information for imbalanced-learn from https://files.pythonhosted.org/packages/a3/9e/fbe60a768502af54563dcb59ca7856f5a8833b3ad5ada658922e1ab09b7f/imbalanced_learn-0.11.0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/235.6 kB ? eta -:--:--
#    ------------------------------- -------- 184.3/235.6 kB 5.4 MB/s eta 0:00:01
#    ---------------------------------------- 235.6/235.6 kB 3.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: imbalanced-learn
#     Found existing installation: imbalanced-learn 0.10.1
#     Uninstalling imbalanced-learn-0.10.1:
#       Successfully uninstalled imbalanced-learn-0.10.1
# ...

# %%
from imblearn.over_sampling import SMOTE
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 from imblearn.over_sampling import SMOTE
#
# File ~\anaconda3\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# ...

# %%
print("Class distribution before oversampling:")
print("Class 0 samples:", np.sum(y == 0))
print("Class 1 samples:", np.sum(y == 1))

smote = SMOTE(sampling_strategy='auto', random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

print("\nClass distribution after oversampling:")
print("Class 0 samples:", np.sum(y_resampled == 0))
print("Class 1 samples:", np.sum(y_resampled == 1))
# Out:
# Class distribution before oversampling:
# Class 0 samples: 138
# Class 1 samples: 165
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[108], line 5
#       2 print("Class 0 samples:", np.sum(y == 0))
#       3 print("Class 1 samples:", np.sum(y == 1))
# ----> 5 smote = SMOTE(sampling_strategy='auto', random_state=42)
#       6 X_resampled, y_resampled = smote.fit_resample(X, y)
#       8 print("\nClass distribution after oversampling:")
#
# NameError: name 'SMOTE' is not defined

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns)
X_test = pd.DataFrame(X_test_scaled, columns=X_test.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 3
#       1 scaler = StandardScaler()
# ----> 3 X_train_scaled = scaler.fit_transform(X_train)
#       4 X_test_scaled = scaler.transform(X_test)
#       6 X_train = pd.DataFrame(X_train_scaled, columns=X_train.columns)
#
# NameError: name 'X_train' is not defined

# %% [markdown]
# #**Apprentissage supervisé**

# %% [markdown]
# **1- Préparation des données (train & test)**

# %%
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix,ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split

# %%
X = df.drop("output", axis=1)
y = df["output"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=39 )

# %% [markdown]
#  **2- K-Nearest Neighbors (KNN)**

# %%
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# Tunning des paramètres

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': [3, 5, 7, 9], 'weights': ['uniform', 'distance'], 'p': [1, 2]}
knn = KNeighborsClassifier()
grid_search = GridSearchCV(knn, param_grid, cv=5, scoring='accuracy')

# %% [markdown]
# Training

# %%
grid_search.fit(X_train, y_train)
print("Best Parameters: ", grid_search.best_params_)
# Out:
# Best Parameters:  {'n_neighbors': 9, 'p': 1, 'weights': 'uniform'}

# %% [markdown]
# Test

# %%
best_knn = grid_search.best_estimator_
y_pred_knn = best_knn.predict(X_test)

# %% [markdown]
# Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred_knn)
print("Accuracy on Test Set: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy on Test Set: 78.02%

# %% [markdown]
# Autres mésures

# %%
print(classification_report(y_test, y_pred_knn, target_names=['0','1']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74        37
#            1       0.83      0.80      0.81        54
#
#     accuracy                           0.78        91
#    macro avg       0.77      0.78      0.77        91
# weighted avg       0.78      0.78      0.78        91

# %% [markdown]
# Matrice de confusion

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_knn)).plot()

# %% [markdown]
# **3- Naive Bayesienne (NB)**

# %%
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# Training

# %%
nb = GaussianNB()
nb.fit(X_train,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Test

# %%
y_pred_nb = nb.predict(X_test)

# %% [markdown]
# Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred_nb)
print("Accuracy on Test Set: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy on Test Set: 85.71%

# %% [markdown]
# Autres mésures

# %%
print(classification_report(y_test, y_pred_nb, target_names=["0","1"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.81      0.82        37
#            1       0.87      0.89      0.88        54
#
#     accuracy                           0.86        91
#    macro avg       0.85      0.85      0.85        91
# weighted avg       0.86      0.86      0.86        91

# %% [markdown]
# Matrice de confusion

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_nb)).plot()

# %% [markdown]
# **4- Decision Tree (DT)**

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Training

# %%
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Test

# %%
y_pred_dt = dt.predict(X_test)

# %% [markdown]
# Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred_dt)
print("Accuracy on Test Set: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy on Test Set: 79.12%

# %% [markdown]
# Autres mésures

# %%
print(classification_report(y_test, y_pred_dt, target_names=["0", "1"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.65      0.72        37
#            1       0.79      0.89      0.83        54
#
#     accuracy                           0.79        91
#    macro avg       0.79      0.77      0.78        91
# weighted avg       0.79      0.79      0.79        91

# %% [markdown]
# Matrice de confusion

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_dt)).plot()

# %% [markdown]
# **5- Support Vector Machines (SVM)**

# %%
from sklearn.svm import SVC

# %% [markdown]
# Training

# %%
svc_model = SVC(kernel='rbf', gamma='auto')
svc_model.fit(X_train,y_train)
# Out:
# SVC(gamma='auto')

# %% [markdown]
# Test

# %%
y_pred_svc = svc_model.predict(X_test)

# %% [markdown]
# Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred_svc)
print("Accuracy on Test Set: {:.2f}%".format(accuracy * 100))
# Out:
# Accuracy on Test Set: 53.85%

# %% [markdown]
# Autres mésures

# %%
print(classification_report(y_test, y_pred_svc, target_names=["0", "1"]))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      0.16      0.22        37
#            1       0.58      0.80      0.67        54
#
#     accuracy                           0.54        91
#    macro avg       0.47      0.48      0.45        91
# weighted avg       0.49      0.54      0.49        91

# %% [markdown]
# Matrice de confusion

# %%
ConfusionMatrixDisplay(confusion_matrix(y_test, y_pred_svc)).plot()

# %% [markdown]
# #**Apprentissage non-supervisé**

# %% [markdown]
# # **K-MEANS**

# %%
from sklearn.cluster import KMeans
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
from scipy.spatial import distance
from itertools import combinations

# %%
X = df.drop('output', axis=1)
y_true = df['output']

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
num_clusters = 2
kmeans = KMeans(n_clusters=num_clusters, init='k-means++', max_iter=300, n_init=10, random_state=0)
kmeans.fit(X_scaled)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# KMeans(n_clusters=2, n_init=10, random_state=0)

# %%
centers = kmeans.cluster_centers_
labels = kmeans.labels_
inertie = kmeans.inertia_
unique_labels, counts = np.unique(labels, return_counts=True)

for cluster, count in zip(unique_labels, counts):
    print(f"Cluster {cluster}: {count} éléments")
# Out:
# Cluster 0: 106 éléments
# Cluster 1: 197 éléments

# %%
label_mapping = {}
for cluster in range(num_clusters):
    cluster_indices = np.where(labels == cluster)[0]
    true_labels_in_cluster = y_true.iloc[cluster_indices]
    most_common_label = np.argmax(np.bincount(true_labels_in_cluster))
    label_mapping[cluster] = most_common_label

predicted_labels = np.vectorize(label_mapping.get)(labels)

accuracy = accuracy_score(y_true, predicted_labels)
print(f'Accuracy : {accuracy}')

for i in range(len(df)):
    print(df.iloc[i].values, y_true.iloc[i], predicted_labels[i])
# Out:
# Accuracy : 0.8151815181518152
# [ 63.    1.    3.  145.    0.  150.    0.    2.3   0.    0.    1.    1. ] 1 1
# [ 37.    1.    2.  130.    1.  187.    0.    3.5   0.    0.    2.    1. ] 1 1
# [ 41.    0.    1.  130.    0.  172.    0.    1.4   2.    0.    2.    1. ] 1 1
# [ 56.    1.    1.  120.    1.  178.    0.    0.8   2.    0.    2.    1. ] 1 1
# [ 57.    0.    0.  120.    1.  163.    1.    0.6   2.    0.    2.    1. ] 1 1
# [ 57.    1.    0.  140.    1.  148.    0.    0.4   1.    0.    1.    1. ] 1 1
# [ 56.    0.    1.  140.    0.  153.    0.    1.3   1.    0.    2.    1. ] 1 1
# [ 44.   1.   1. 120.   1. 173.   0.   0.   2.   0.   3.   1.] 1 1
# [ 52.    1.    2.  172.    1.  162.    0.    0.5   2.    0.    3.    1. ] 1 1
# [ 57.    1.    2.  150.    1.  174.    0.    1.6   2.    0.    2.    1. ] 1 1
# [ 54.    1.    0.  140.    1.  160.    0.    1.2   2.    0.    2.    1. ] 1 1
# [ 48.    0.    2.  130.    1.  139.    0.    0.2   2.    0.    2.    1. ] 1 1
# ...

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %%
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

plt.subplot(1, 2, 1)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=y_true, cmap='viridis', edgecolors='k', s=20)
plt.title('Clusters Originals')
plt.xlabel('Première composante principale')
plt.ylabel('Deuxième composante principale')


plt.subplot(1, 2, 2)
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels, cmap='viridis', edgecolors='k', s=20)
plt.title('Clusters identifiés par K-Means')
plt.xlabel('Première composante principale')
plt.ylabel('Deuxième composante principale')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## **Determiner le nombre de clusters**

# %% [markdown]
# ### Méthode du Coude (Elbow Method) :

# %%
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %%
plt.plot(range(1, 11), wcss, marker='o')
plt.title('Méthode du coude pour trouver le nombre optimal de clusters')
plt.xlabel('Nombre de clusters')
plt.ylabel('WCSS (Somme des carrés intra-cluster)')
plt.show()

# %% [markdown]
# ### Coefficient Silhouette

# %%
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    cluster_labels = kmeans.fit_predict(X_scaled)
    silhouette_avg = silhouette_score(X_scaled, cluster_labels)
    print(f"Silhouette Score pour nombre de clusters {i} : {silhouette_avg}")
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Silhouette Score pour nombre de clusters 2 : 0.19201851636008116
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Silhouette Score pour nombre de clusters 3 : 0.1385933818175985
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %% [markdown]
# ### Coefficient de Davies-Bouldin

# %%
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    cluster_labels = kmeans.fit_predict(X_scaled)
    db_score = davies_bouldin_score(X_scaled, cluster_labels)
    print(f"Coefficient de Davies-Bouldin pour nombre de clusters {i} : {db_score}")
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Coefficient de Davies-Bouldin pour nombre de clusters 2 : 1.9904430415961256
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# Coefficient de Davies-Bouldin pour nombre de clusters 3 : 2.1689709741993273
# ...

# %%
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    cluster_labels = kmeans.fit_predict(X_scaled)

    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_labels, cmap='viridis', edgecolors='k', s=50)
    plt.title(f"Clusters identifiés par K-means avec k est : {i} ")
    plt.xlabel('Première composante principale')
    plt.ylabel('Deuxième composante principale')
    plt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1436: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# ...

# %% [markdown]
# # **Clustering Hierarchique**

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.decomposition import PCA

# %%
n_clusters = 2

cluster = AgglomerativeClustering(n_clusters=n_clusters, metric='euclidean', linkage='complete')
cluster_labels = cluster.fit_predict(X_scaled)
unique_labels, counts = np.unique(cluster_labels, return_counts=True)

# %%
for cluster, count in zip(unique_labels, counts):
    print(f"Cluster {cluster}: {count} éléments")
# Out:
# Cluster 0: 282 éléments
# Cluster 1: 21 éléments

# %% [markdown]
# ### Dendogramme

# %%
z = linkage(X_scaled,"ward")

dendrogram(z,truncate_mode= "lastp", p =20, leaf_rotation=45,leaf_font_size=15, show_contracted=True)
plt.title("Truncated Hierachial Clustering Dendrogram")
plt.xlabel("Cluster Size")
plt.ylabel("Distance")

plt.axhline(y=15)
plt.axhline(5)
plt.axhline(10)
plt.show()

# %%
z = linkage(X_scaled,"average")

dendrogram(z,truncate_mode= "lastp", p =20, leaf_rotation=45,leaf_font_size=15, show_contracted=True)
plt.title("Truncated Hierachial Clustering Dendrogram")
plt.xlabel("Cluster Size")
plt.ylabel("Distance")

plt.axhline(y=15)
plt.axhline(5)
plt.axhline(10)
plt.show()

# %%
z = linkage(X_scaled,"complete")

dendrogram(z,truncate_mode= "lastp", p =20, leaf_rotation=45,leaf_font_size=15, show_contracted=True)
plt.title("Truncated Hierachial Clustering Dendrogram")
plt.xlabel("Cluster Size")
plt.ylabel("Distance")

plt.axhline(y=15)
plt.axhline(5)
plt.axhline(10)
plt.show()

# %%
z = linkage(X_scaled,"single")


dendrogram(z,truncate_mode= "lastp", p =20, leaf_rotation=45,leaf_font_size=15, show_contracted=True)
plt.title("Truncated Hierachial Clustering Dendrogram")
plt.xlabel("Cluster Size")
plt.ylabel("Distance")

plt.axhline(y=15)
plt.axhline(5)
plt.axhline(10)
plt.show()

# %%
# Tracer le graphique des clusters

for i in range(2, 11):
    cluster = AgglomerativeClustering(n_clusters=i, metric='euclidean', linkage='complete')
    cluster_labels = cluster.fit_predict(X_scaled)

    plt.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_labels, cmap='viridis', edgecolors='k', s=50)
    plt.title(f"Clusters identifiés par Clusteri avec k est : {i} ")
    plt.xlabel('Première composante principale')
    plt.ylabel('Deuxième composante principale')
    plt.show()

# %%
for i in range(2, 11):
    cluster = AgglomerativeClustering(n_clusters=i, metric='euclidean', linkage='average')
    cluster_labels = cluster.fit_predict(X_scaled)
    silhouette_avg = silhouette_score(X_scaled, cluster_labels)
    print(f"Silhouette Score pour nombre de clusters {i} : {silhouette_avg}")
# Out:
# Silhouette Score pour nombre de clusters 2 : 0.3070303987508227
# Silhouette Score pour nombre de clusters 3 : 0.2116815305351958
# Silhouette Score pour nombre de clusters 4 : 0.12458822807742909
# Silhouette Score pour nombre de clusters 5 : 0.05613765784171341
# Silhouette Score pour nombre de clusters 6 : 0.039729590759482944
# Silhouette Score pour nombre de clusters 7 : 0.09397366263274165
# Silhouette Score pour nombre de clusters 8 : 0.1012979158652774
# Silhouette Score pour nombre de clusters 9 : 0.11485494579971113
# Silhouette Score pour nombre de clusters 10 : 0.10197251566823658
